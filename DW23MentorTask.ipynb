# %% [markdown]
# **Assignment 1**

# %%
import pandas as pd

# %%
column_names = ['Website', 'Employees', 'News',  'Languages', 'National', 'International']

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/datasets/balance+scale',names = column_names)

# %%
df
# Out:
#                                                Website Employees News  \
# 0    <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...       NaN  NaN
# 1                                               <html>       NaN  NaN
# 2                                               <head>       NaN  NaN
# 3    <title>UCI Machine Learning Repository: Balanc...       NaN  NaN
# 4                             <!-- Stylesheet link -->       NaN  NaN
# ..                                                 ...       ...  ...
# 234           <a href="http://cml.ics.uci.edu">CML</a>       NaN  NaN
# 235                                            </span>       NaN  NaN
# 236                                          </center>       NaN  NaN
# 237                                            </body>       NaN  NaN
# 238                                            </html>       NaN  NaN
#
#     Languages National International
# 0         NaN      NaN           NaN
# 1         NaN      NaN           NaN
# ...

# %%
df.isnull().sum()
# Out:
# Website            0
# Employees        217
# News             226
# Languages        230
# National         231
# International    235
# dtype: int64

# %%
df = df.fillna({'Website':33,'Employees':2500,'News':46,'Languages':12, 'National':26, 'International':4})
df
# Out:
#                                                Website Employees News  \
# 0    <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...      2500   46
# 1                                               <html>      2500   46
# 2                                               <head>      2500   46
# 3    <title>UCI Machine Learning Repository: Balanc...      2500   46
# 4                             <!-- Stylesheet link -->      2500   46
# ..                                                 ...       ...  ...
# 234           <a href="http://cml.ics.uci.edu">CML</a>      2500   46
# 235                                            </span>      2500   46
# 236                                          </center>      2500   46
# 237                                            </body>      2500   46
# 238                                            </html>      2500   46
#
#     Languages National International
# 0          12       26             4
# 1          12       26             4
# ...

# %%
df = df.fillna(6)
df
# Out:
#                                                Website Employees News  \
# 0    <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...      2500   46
# 1                                               <html>      2500   46
# 2                                               <head>      2500   46
# 3    <title>UCI Machine Learning Repository: Balanc...      2500   46
# 4                             <!-- Stylesheet link -->      2500   46
# ..                                                 ...       ...  ...
# 234           <a href="http://cml.ics.uci.edu">CML</a>      2500   46
# 235                                            </span>      2500   46
# 236                                          </center>      2500   46
# 237                                            </body>      2500   46
# 238                                            </html>      2500   46
#
#     Languages National International
# 0          12       26             4
# 1          12       26             4
# ...

# %%
df.shape
# Out:
# (239, 6)

# %%
df.head(10)
# Out:
#                                              Website Employees News Languages  \
# 0  <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...      2500   46        12
# 1                                             <html>      2500   46        12
# 2                                             <head>      2500   46        12
# 3  <title>UCI Machine Learning Repository: Balanc...      2500   46        12
# 4                           <!-- Stylesheet link -->      2500   46        12
# 5  <link rel="stylesheet" type="text/css" href="....      2500   46        12
# 6  <script language="JavaScript" type="text/javas...      2500   46        12
# 7                                               <!--      2500   46        12
# 8                        function checkform ( form )      2500   46        12
# 9                                                  {      2500   46        12
#
#   National International
# 0       26             4
# 1       26             4
# 2       26             4
# ...

# %%
df.tail(10)
# Out:
#                                                Website Employees News  \
# 229                              <span class="normal">      2500   46
# 230  <a href="../about.html">About</a>&nbsp;&nbsp;|...      2500   46
# 231  <a href="../citation_policy.html">Citation Pol...      2500   46
# 232  <a href="../donation_policy.html">Donation Pol...      2500   46
# 233  <a href="../contact.html">Contact</a>&nbsp;&nb...      2500   46
# 234           <a href="http://cml.ics.uci.edu">CML</a>      2500   46
# 235                                            </span>      2500   46
# 236                                          </center>      2500   46
# 237                                            </body>      2500   46
# 238                                            </html>      2500   46
#
#     Languages National International
# 229        12       26             4
# 230        12       26             4
# 231        12       26             4
# 232        12       26             4
# ...

# %%
df.describe()
# Out:
#        Website  Employees  News  Languages  National  International
# count      239        239   239        239       239            239
# unique     192         18    11          7         7              5
# top     <br />       2500    46         12        26              4
# freq         7        217   226        230       231            235

# %%
df.isnull().sum()
# Out:
# Website          0
# Employees        0
# News             0
# Languages        0
# National         0
# International    0
# dtype: int64

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of                                                Website Employees News  \
# 0    <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...       NaN  NaN
# 1                                               <html>       NaN  NaN
# 2                                               <head>       NaN  NaN
# 3    <title>UCI Machine Learning Repository: Balanc...       NaN  NaN
# 4                             <!-- Stylesheet link -->       NaN  NaN
# ..                                                 ...       ...  ...
# 234           <a href="http://cml.ics.uci.edu">CML</a>       NaN  NaN
# 235                                            </span>       NaN  NaN
# 236                                          </center>       NaN  NaN
# 237                                            </body>       NaN  NaN
# 238                                            </html>       NaN  NaN
#
#     Languages National International
# 0         NaN      NaN           NaN
# ...

# %%
X = df.iloc[:,0:-1]
X
# Out:
#                                                Website Employees News  \
# 0    <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...      2500   46
# 1                                               <html>      2500   46
# 2                                               <head>      2500   46
# 3    <title>UCI Machine Learning Repository: Balanc...      2500   46
# 4                             <!-- Stylesheet link -->      2500   46
# ..                                                 ...       ...  ...
# 234           <a href="http://cml.ics.uci.edu">CML</a>      2500   46
# 235                                            </span>      2500   46
# 236                                          </center>      2500   46
# 237                                            </body>      2500   46
# 238                                            </html>      2500   46
#
#     Languages National
# 0          12       26
# 1          12       26
# 2          12       26
# 3          12       26
# ...

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type('website')
# Out:
# str

# %%
type('Languages')
# Out:
# str

# %%
type('Employees'[1])
# Out:
# str

# %%
type('News')
# Out:
# str

# %%
type('National')
# Out:
# str

# %%
X.shape
# Out:
# (239, 5)

# %%
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      4
# 1      4
# 2      4
# 3      4
# 4      4
#       ..
# 234    4
# 235    4
# 236    4
# 237    4
# 238    4
# Name: International, Length: 239, dtype: object

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
type(0)
# Out:
# int

# %%
type(1)
# Out:
# int

# %%
type(3)
# Out:
# int

# %%
type(5)
# Out:
# int

# %%
y.shape
# Out:
# (239,)

# %%
len1 = df['Website']
len1
# Out:
# 0      <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...
# 1                                                 <html>
# 2                                                 <head>
# 3      <title>UCI Machine Learning Repository: Balanc...
# 4                               <!-- Stylesheet link -->
#                              ...
# 234             <a href="http://cml.ics.uci.edu">CML</a>
# 235                                              </span>
# 236                                            </center>
# 237                                              </body>
# 238                                              </html>
# Name: Website, Length: 239, dtype: object

# %%
df.dtypes
# Out:
# Website          object
# Employees        object
# News             object
# Languages        object
# National         object
# International    object
# dtype: object

# %%
df
# Out:
#                                                Website Employees News  \
# 0    <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...      2500   46
# 1                                               <html>      2500   46
# 2                                               <head>      2500   46
# 3    <title>UCI Machine Learning Repository: Balanc...      2500   46
# 4                             <!-- Stylesheet link -->      2500   46
# ..                                                 ...       ...  ...
# 234           <a href="http://cml.ics.uci.edu">CML</a>      2500   46
# 235                                            </span>      2500   46
# 236                                          </center>      2500   46
# 237                                            </body>      2500   46
# 238                                            </html>      2500   46
#
#     Languages National International
# 0          12       26             4
# 1          12       26             4
# ...

# %%
df['Website'].unique()
# Out:
# array(['<!DOCTYPE HTML PUBLIC \\"-//W3C//DTD HTML 4.01 Transitional//EN\\">',
#        '<html>', '<head>',
#        '<title>UCI Machine Learning Repository: Balance Scale Data Set</title>',
#        '<!-- Stylesheet link -->',
#        '<link rel="stylesheet" type="text/css" href="../assets/ml.css" />',
#        '<script language="JavaScript" type="text/javascript">', '<!--',
#        'function checkform ( form )', '{',
#        '  // see http://www.thesitewizard.com/archive/validation.shtml',
#        '  // for an explanation of this script and how to use it on your',
#        '  // own website', '  // ** START **',
#        '  if (form.q.value == "")', '  {',
#        '    alert( "Please enter search terms." );',
#        '    form.q.focus();', '    return false ;', '  }',
#        '  if (getCheckedValue(form.sitesearch) == "ics.uci.edu" && form.q.value.indexOf("site:archive.ics.uci.edu/ml") == -1)',
#        '    form.q.value = form.q.value + " site:archive.ics.uci.edu/ml";',
# ...

# %%
df['Website'].nunique()
# Out:
# 192

# %%
df
# Out:
#                                                Website Employees News  \
# 0    <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...      2500   46
# 1                                               <html>      2500   46
# 2                                               <head>      2500   46
# 3    <title>UCI Machine Learning Repository: Balanc...      2500   46
# 4                             <!-- Stylesheet link -->      2500   46
# ..                                                 ...       ...  ...
# 234           <a href="http://cml.ics.uci.edu">CML</a>      2500   46
# 235                                            </span>      2500   46
# 236                                          </center>      2500   46
# 237                                            </body>      2500   46
# 238                                            </html>      2500   46
#
#     Languages National International
# 0          12       26             4
# 1          12       26             4
# ...

# %%
#Adding a new column
df['Total_Factors'] = df.iloc[:,2:5].sum(axis=1)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#                                                Website Employees News  \
# 0    <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...      2500   46
# 1                                               <html>      2500   46
# 2                                               <head>      2500   46
# 3    <title>UCI Machine Learning Repository: Balanc...      2500   46
# 4                             <!-- Stylesheet link -->      2500   46
# ..                                                 ...       ...  ...
# 234           <a href="http://cml.ics.uci.edu">CML</a>      2500   46
# 235                                            </span>      2500   46
# ...

# %%
df = df.drop(['Total_Factors'],axis=1)
df
# Out:
#                                                Website Employees News  \
# 0    <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...      2500   46
# 1                                               <html>      2500   46
# 2                                               <head>      2500   46
# 3    <title>UCI Machine Learning Repository: Balanc...      2500   46
# 4                             <!-- Stylesheet link -->      2500   46
# ..                                                 ...       ...  ...
# 234           <a href="http://cml.ics.uci.edu">CML</a>      2500   46
# 235                                            </span>      2500   46
# 236                                          </center>      2500   46
# 237                                            </body>      2500   46
# 238                                            </html>      2500   46
#
#     Languages National International
# 0          12       26             4
# 1          12       26             4
# ...

# %%
df['Values'] = df.iloc[:4:6].sum(axis=1)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#                                                Website Employees News  \
# 0    <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...      2500   46
# 1                                               <html>      2500   46
# 2                                               <head>      2500   46
# 3    <title>UCI Machine Learning Repository: Balanc...      2500   46
# 4                             <!-- Stylesheet link -->      2500   46
# ..                                                 ...       ...  ...
# 234           <a href="http://cml.ics.uci.edu">CML</a>      2500   46
# 235                                            </span>      2500   46
# ...

# %%
df['National'].nunique()
# Out:
# 7

# %%
df['International'].unique()
# Out:
# array([4,
#        ' and the right distance.  The correct way to find the class is the greater of  (left-distance * left-weight) and (right-distance * right-weight).  If they are equal',
#        ' pp. 61-116.  New York: Academic Press ',
#        ' pp. 99-161. Cambridge',
#        ' W. (1994).  Modeling Cognitive Development on Balance Scale Phenomena. Machine Learning'],
#       dtype=object)

# %%
df.insert(6,'Popularity',df['News'])
df

# %%
df.insert(6,'Celebrity',15)
df
# Out:
#                                                Website Employees News  \
# 0    <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...      2500   46
# 1                                               <html>      2500   46
# 2                                               <head>      2500   46
# 3    <title>UCI Machine Learning Repository: Balanc...      2500   46
# 4                             <!-- Stylesheet link -->      2500   46
# ..                                                 ...       ...  ...
# 234           <a href="http://cml.ics.uci.edu">CML</a>      2500   46
# 235                                            </span>      2500   46
# 236                                          </center>      2500   46
# 237                                            </body>      2500   46
# 238                                            </html>      2500   46
#
#     Languages National International  Celebrity Popularity  Values
# ...

# %%
df=df.drop(['International','Values'],axis=1)
df
# Out:
#                                                Website Employees News  \
# 0    <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...      2500   46
# 1                                               <html>      2500   46
# 2                                               <head>      2500   46
# 3    <title>UCI Machine Learning Repository: Balanc...      2500   46
# 4                             <!-- Stylesheet link -->      2500   46
# ..                                                 ...       ...  ...
# 234           <a href="http://cml.ics.uci.edu">CML</a>      2500   46
# 235                                            </span>      2500   46
# 236                                          </center>      2500   46
# 237                                            </body>      2500   46
# 238                                            </html>      2500   46
#
#     Languages National  Celebrity Popularity
# 0          12       26         15         46
# ...

# %%
df = df.rename(columns={'Employees':'Journalists'})
df
# Out:
#                                                Website Journalists News  \
# 0    <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...        2500   46
# 1                                               <html>        2500   46
# 2                                               <head>        2500   46
# 3    <title>UCI Machine Learning Repository: Balanc...        2500   46
# 4                             <!-- Stylesheet link -->        2500   46
# ..                                                 ...         ...  ...
# 234           <a href="http://cml.ics.uci.edu">CML</a>        2500   46
# 235                                            </span>        2500   46
# 236                                          </center>        2500   46
# 237                                            </body>        2500   46
# 238                                            </html>        2500   46
#
#     Languages National  Celebrity Popularity
# 0          12       26         15         46
# ...

# %%
df.columns
# Out:
# Index(['Website', 'Journalists', 'News', 'Languages', 'National', 'Celebrity',
#        'Popularity'],
#       dtype='object')

# %%
df.columns = ['Website2', 'Journalists', 'News', 'Languages5', 'National', 'Celebrity','Popularity']

# %%
df
# Out:
#                                               Website2 Journalists News  \
# 0    <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...        2500   46
# 1                                               <html>        2500   46
# 2                                               <head>        2500   46
# 3    <title>UCI Machine Learning Repository: Balanc...        2500   46
# 4                             <!-- Stylesheet link -->        2500   46
# ..                                                 ...         ...  ...
# 234           <a href="http://cml.ics.uci.edu">CML</a>        2500   46
# 235                                            </span>        2500   46
# 236                                          </center>        2500   46
# 237                                            </body>        2500   46
# 238                                            </html>        2500   46
#
#     Languages5 National  Celebrity Popularity
# 0           12       26         15         46
# ...

# %%
df = df.rename(columns = {'Website2':'Sources','Languages5':'Languages'})
df
# Out:
#                                                Sources Journalists News  \
# 0    <!DOCTYPE HTML PUBLIC \"-//W3C//DTD HTML 4.01 ...        2500   46
# 1                                               <html>        2500   46
# 2                                               <head>        2500   46
# 3    <title>UCI Machine Learning Repository: Balanc...        2500   46
# 4                             <!-- Stylesheet link -->        2500   46
# ..                                                 ...         ...  ...
# 234           <a href="http://cml.ics.uci.edu">CML</a>        2500   46
# 235                                            </span>        2500   46
# 236                                          </center>        2500   46
# 237                                            </body>        2500   46
# 238                                            </html>        2500   46
#
#     Languages National  Celebrity Popularity
# 0          12       26         15         46
# ...

# %%
df.values
# Out:
# array([['<!DOCTYPE HTML PUBLIC \\"-//W3C//DTD HTML 4.01 Transitional//EN\\">',
#         2500, 46, ..., 26, 15, 46],
#        ['<html>', 2500, 46, ..., 26, 15, 46],
#        ['<head>', 2500, 46, ..., 26, 15, 46],
#        ...,
#        ['</center>', 2500, 46, ..., 26, 15, 46],
#        ['</body>', 2500, 46, ..., 26, 15, 46],
#        ['</html>', 2500, 46, ..., 26, 15, 46]], dtype=object)

# %%
type(df.values)
# Out:
# numpy.ndarray

# %% [markdown]
# **Assignment 2**

# %%
#Distribution function

# %%
list1= [1, 1, 1, 5, 5, 3, 1, 3, 3, 1,4, 4, 4, 2, 2, 2, 2]

res = dict((key,list1.count(key)) for key in list1)
print(res)
# Out:
# {1: 5, 5: 2, 3: 3, 4: 3, 2: 4}
